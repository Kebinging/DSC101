# %% [markdown]
# How to get tweets

# %%
import pandas as pd
import numpy as np
import tweepy

# Function to clean tweet text
import re
def clean_tweet(tweet):
    return ' '.join(re.sub(r"(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
# Your credentials
bearer_token = "AAAAAAAAAAAAAAAAAAAAAJma5QEAAAAAn5Bfo27MODFopIjGz1wjGwKhup4%3DkrHnNva3O6vPtTAP0EMKeym800Yj2AEDH8u0oeIN0r8JFPKPsY"

# Authenticate
client = tweepy.Client(bearer_token=bearer_token)

# Example: Search recent tweets about Bitcoin
query = "bitcoin lang:en -is:retweet"
tweets = client.search_recent_tweets(query=query, max_results=10)

for tweet in tweets.data:
    cleaned_tweet = clean_tweet(tweet.text)
    print(cleaned_tweet)
