# %% [markdown]
# Code to warm up kernel

# %%
#Imports
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
#Declare constants
ETH_TICKER = "ETH-USD"
SPX_TICKER = "^GSPC"

# %% [markdown]
# Below is the code to get price of Ether Vs S&P 500 data

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 1. Data Retrieval and DataFrame Creation ---

# Define the ticker symbols
ETH_TICKER = "ETH-USD"
SPX_TICKER = "^GSPC" # Ticker for S&P 500 Index
START_DATE = "2020-01-01"

try:
    # --- FETCH ETH DATA ---
    eth_data = yf.Ticker(ETH_TICKER).history(start=START_DATE, period="5y")
    df_eth = eth_data[['Open', 'High', 'Low', 'Close']].copy()

    # --- FETCH S&P 500 DATA ---
    spx_data = yf.Ticker(SPX_TICKER).history(start=START_DATE, period="5y")
    df_spx = spx_data[['Close']].copy()
    df_spx.rename(columns={'Close': 'SPX_Close'}, inplace=True)


    # --- 2. Data Processing: Resample, Align, and Join ---
    
    # Resample ETH daily data to MONTHLY averages
    df_eth_monthly = df_eth.resample('ME').mean()
    
    # Resample S&P 500 daily data to MONTHLY averages
    df_spx_monthly = df_spx.resample('BM').mean()

    # CRITICAL FIX: Convert both Datetime Indexes to Month Period Indexes for alignment
    df_eth_monthly.index = df_eth_monthly.index.to_period('MS')
    df_spx_monthly.index = df_spx_monthly.index.to_period('MS')

    # Join the two monthly DataFrames on their common Period Index
    df_combined_monthly = df_eth_monthly.join(
        df_spx_monthly, 
        how='inner'
    )
    
    # Convert the PeriodIndex back to a DatetimeIndex for plotting
    df_combined_monthly.index = df_combined_monthly.index.to_timestamp()

    # --- Summary of Combined Table ---
    print(f"--- Combined Monthly Average Data (ETH-USD and S&P 500) ---")
    print(df_combined_monthly.head().to_markdown())
    print("...")
    print(df_combined_monthly.tail().to_markdown())

except Exception as e:
    print(f"An error occurred while fetching data: {e}")
    print("Please ensure you have the 'yfinance' library installed: pip install yfinance")
    exit()

# %% [markdown]
# Below is the code to get the Data for BTC vs S&P 500

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 1. Data Retrieval and DataFrame Creation ---

# Define the ticker symbols
BTC_TICKER = "BTC-USD"
SPX_TICKER = "^GSPC" 
START_DATE = "2021-01-01"

try:
    # --- FETCH ETH DATA ---
    btc_data = yf.Ticker(BTC_TICKER).history(start=START_DATE, period="4y")
    df_btc = btc_data[['Open', 'High', 'Low', 'Close']].copy()

    # --- FETCH S&P 500 DATA ---
    spx_data = yf.Ticker(SPX_TICKER).history(start=START_DATE, period="4y")
    df_spx = spx_data[['Close']].copy()
    df_spx.rename(columns={'Close': 'SPX_Close'}, inplace=True)


    # --- 2. Data Processing: Resample, Align, and Join ---
    
    # Resample BTC daily data to MONTHLY averages
    df_btc_monthly = df_btc.resample('ME').mean()
    
    # Resample S&P 500 daily data to MONTHLY averages
    df_spx_monthly = df_spx.resample('BM').mean()

    # CRITICAL FIX: Convert both Datetime Indexes to Month Period Indexes for alignment
    df_btc_monthly.index = df_btc_monthly.index.to_period('M')
    df_spx_monthly.index = df_spx_monthly.index.to_period('M')

    # Join the two monthly DataFrames on their common Period Index
    df_combined_monthly = df_btc_monthly.join(
        df_spx_monthly, 
        how='inner'
    )
    
    # Convert the PeriodIndex back to a DatetimeIndex for plotting
    df_combined_monthly.index = df_combined_monthly.index.to_timestamp()

    # --- Summary of Combined Table ---
    print(f"--- Combined Monthly Average Data (VTC-USD and S&P 500) ---")
    print(df_combined_monthly.head().to_markdown())
    print("...")
    print(df_combined_monthly.tail().to_markdown())

except Exception as e:
    print(f"An error occurred while fetching data: {e}")
    exit()

# %% [markdown]
# BTC HASHRATE

# %%
import pandas as pd

FILE_PATH = "C:\\Users\\Kevin Ivander\\Documents\\GitHub\\DSC101\\csv_files\\hashrateBTC.csv"
START_DATE = '2021-01-01 00:00:00'
END_DATE = '2024-12-31 00:00:00'

df_hashrate_data = pd.read_csv(
    FILE_PATH,
    sep=';',
    names = ['DateTime', 'Hashrate'],
    index_col='DateTime',
    parse_dates=['DateTime'],
    skiprows=1,
    header=None
    )
df_hashrate = df_hashrate_data.loc[START_DATE:END_DATE]

#print(df_hashrate.head())
#print(df_hashrate.tail())

df_hashrate.index = pd.to_datetime(df_hashrate.index)
df_hashrate['Hashrate'] = pd.to_numeric(df_hashrate['Hashrate'].astype(float))
monthly_avg = df_hashrate.resample('MS').mean()
print(monthly_avg.head())
print(monthly_avg.tail())

# %%
df_combined_monthly = df_combined_monthly.join(monthly_avg)

# %%
df_combined_monthly.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  34652.961694  36206.557082  32705.655998  34761.649950
# 2021-02-01  45874.967215  47710.414621  44197.377302  46306.798968
# 2021-03-01  54544.678175  56250.979083  52964.134703  54998.008695
# 2021-04-01  57251.256250  58557.342057  55604.271094  57206.720052
# 2021-05-01  47105.828503  48775.041835  44434.530620  46443.286668
#
#               SPX_Close      Hashrate
# Date
# 2021-01-01  3793.748432  1.490482e+20
# 2021-02-01  3883.432116  1.551086e+20
# 2021-03-01  3910.508280  1.595774e+20
# 2021-04-01  4141.176200  1.572286e+20
# 2021-05-01  4167.849536  1.618050e+20

# %%
# Define parameters
FILE_PATH = r'C:\\Users\\Kevin Ivander\\Documents\\GitHub\\DSC101\\CryptoGreedFear.csv'
START_DATE = '2020-01-01 00:00:00'
END_DATE = '2024-12-31 00:00:00'

# Load the data
df_fng_data = pd.read_csv(
    FILE_PATH
)

# Preprocessing: Convert 'date' to datetime and set as index
df_fng_data['date'] = pd.to_datetime(df_fng_data['date'])
df_fng_data = df_fng_data.set_index('date')

# CRUCIAL: Sort the index for correct date slicing, resolving the previous KeyError
df_fng_data = df_fng_data.sort_index()

# Filter by date range
df_fng = df_fng_data.loc[START_DATE:END_DATE]

#Resample to monthly frequency and calculate mean
monthly_avg = df_fng['fng_value'].resample('MS').mean()

# Convert the Series to a DataFrame for cleaner display
monthly_avg_df = monthly_avg.to_frame(name='Mean FNG Value')
monthly_avg_df.index.name = 'Month Start Date'
# --- Display and Save ---

print("--- Full Monthly Average Table ---")
# Display the full DataFrame
print(monthly_avg_df)

# Save the data to a CSV file for easy access
output_file = 'monthly_fng_averages_2021_2024.csv'
monthly_avg_df.to_csv(output_file)
print(f"\nData saved to {output_file}")
